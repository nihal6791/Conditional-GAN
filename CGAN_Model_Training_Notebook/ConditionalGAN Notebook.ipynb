# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder

# %%
# !cp -r /kaggle/input/pytorch-congan/pytorch-ConGAN /kaggle/working/

# %%
# !ls /kaggle/working/
# Out:
# pytorch-ConGAN

# %%
# !cp -r /kaggle/input/roadcrackds/Road_Crack_Dataset_Cleaned_labled  /kaggle/working/

# %%
# !python /kaggle/working/pytorch-ConGAN/train.py
# Out:
# Using device: cuda
# Number of classes: 8
# Classes: ['class_0', 'class_1', 'class_2', 'class_3', 'class_4', 'class_5', 'class_6', 'class_7']
# Batch size: 64
# Training steps: 1600
# Training finished!

# %%
# !ls /kaggle/working/pytorch-ConGAN/generate_class_4.py
# Out:
# /kaggle/working/pytorch-ConGAN/generate_class_4.py

# %%
# !python /kaggle/working/pytorch-ConGAN/generate_class_4.py  --batch_size 32  --num_images 160
# Out:
# Using device: cuda
# /kaggle/working/pytorch-ConGAN/generate_class_4.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
